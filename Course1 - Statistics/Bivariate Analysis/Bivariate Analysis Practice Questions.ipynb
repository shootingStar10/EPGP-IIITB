# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('currencies.csv')
data.shape
# Out:
# (11, 52)

# %%
data.head()
# Out:
#         Currency  Chinese Yuan     Euro  Japanese Yen  U.K. Pound Sterling  \
# 0  July 01, 2016       9.29446  1.25367       143.645              1.05054
# 1  July 05, 2016       9.31515  1.25322       142.715              1.06143
# 2  July 06, 2016       9.31697  1.25834       140.540              1.07300
# 3  July 07, 2016       9.31315  1.25737       140.640              1.06911
# 4  July 08, 2016       9.31350  1.25797       140.510              1.07261
#
#    U.S. Dollar  Algerian Dinar  Australian Dollar  Bahrain Dinar  \
# 0      1.39596             NaN            1.87126       0.524882
# 1      1.39684         154.063            1.85825       0.525213
# 2      1.39286         154.094            1.87313       0.523717
# 3      1.39316         153.957            1.85236       0.523829
# 4      1.39257         154.062            1.85974       0.523607
#
#    Botswana Pula  ...  South African Rand  Sri Lanka Rupee  Swedish Krona  \
# ...

# %% [markdown]
# #### Plot a correlation matrix for Euro, Japanese Yen, U.K. Pound Sterling, US Dollar, Chineese Yuan, Australian Dollar and Indian Rupee.

# %%
filter_data = data.loc[:, ['Euro', 'Japanese Yen', 'U.K. Pound Sterling', 'U.S. Dollar', 'Chinese Yuan', 'Australian Dollar', 'Indian Rupee']]

# %%
filter_data
# Out:
#        Euro  Japanese Yen  U.K. Pound Sterling  U.S. Dollar  Chinese Yuan  \
# 0   1.25367       143.645              1.05054      1.39596       9.29446
# 1   1.25322       142.715              1.06143      1.39684       9.31515
# 2   1.25834       140.540              1.07300      1.39286       9.31697
# 3   1.25737       140.640              1.06911      1.39316       9.31315
# 4   1.25797       140.510              1.07261      1.39257       9.31350
# 5   1.25769       139.962              1.07050      1.38962       9.29403
# 6   1.25490       143.369              1.05762      1.39194       9.31021
# 7   1.25716       145.178              1.04680      1.39193       9.31350
# 8   1.24695       144.895              1.05236      1.39122       9.30432
# 9   1.25263       147.268              1.04242      1.39392       9.31532
# 10  1.25652           NaN              1.04952      1.38883       9.30354
#
#     Australian Dollar  Indian Rupee
# 0             1.87126       94.1451
# ...

# %%
filter_data = filter_data[~filter_data['Indian Rupee'].isnull()]

# %%
filter_data = filter_data[~filter_data['Japanese Yen'].isnull()]

# %%
filter_data
# Out:
#       Euro  Japanese Yen  U.K. Pound Sterling  U.S. Dollar  Chinese Yuan  \
# 0  1.25367       143.645              1.05054      1.39596       9.29446
# 1  1.25322       142.715              1.06143      1.39684       9.31515
# 3  1.25737       140.640              1.06911      1.39316       9.31315
# 4  1.25797       140.510              1.07261      1.39257       9.31350
# 5  1.25769       139.962              1.07050      1.38962       9.29403
# 6  1.25490       143.369              1.05762      1.39194       9.31021
# 7  1.25716       145.178              1.04680      1.39193       9.31350
# 8  1.24695       144.895              1.05236      1.39122       9.30432
#
#    Australian Dollar  Indian Rupee
# 0            1.87126       94.1451
# 1            1.85825       94.1513
# 3            1.85236       94.0345
# 4            1.85974       93.9408
# 5            1.83836       93.3027
# 6            1.83439       93.4641
# 7            1.83101       93.5445
# ...

# %%
corr_matrix = filter_data.corr()

# %%
sns.heatmap(data = corr_matrix, cmap = 'Greens', annot=True)
plt.show()
